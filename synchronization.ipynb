# %% [markdown]
# # **Coarse Grained Synchronization**

# %%
import matplotlib.pyplot as plt

# Data
threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]

# Throughput data for Workload 0C-0I-50D
workload_0C_0I_50D_throughput = [149017.97156737105, 638365.7835939993, 616484.80364959, 494238.00855031755, 445193.8540988441, 670016.7504187605, 743798.5793447135, 1186913.4316210693, 1296470.359446407]

# Create the plot for Workload 0C-0I-50D with a blue line
plt.figure(figsize=(10, 6))
plt.plot(threads, workload_0C_0I_50D_throughput, marker='o', label='0C-0I-50D', color='blue')

# Customize the plot for Workload 0C-0I-50D
plt.title('''Coarse Grained Synchronization
Throughput vs. Threads for Workload 0C-0I-50D
Problem Size: 2000''')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# Throughput data for Workload 50C-25I-25D
workload_50C_25I_25D_throughput = [55244.65093667305, 122214.27829413311, 94596.86364098598, 49169.88934316403, 30368.921660329688, 23505.629598288793, 29009.478605388653, 16421.759582155366, 29224.641048346326]

# Create the plot for Workload 50C-25I-25D with a green line
plt.figure(figsize=(10, 6))
plt.plot(threads, workload_50C_25I_25D_throughput, marker='s', label='50C-25I-25D', color='green')

# Customize the plot for Workload 50C-25I-25D
plt.title('''Coarse Grained Synchronization
Throughput vs. Threads for Workload 50C-25I-25D
Problem Size: 2000''')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# Throughput data for Workload 100C-0I-0D
workload_100C_0I_0D_throughput = [423370.0254022015, 505254.64834276476, 824725.2633966309, 727484.3590862795, 785653.9587138845, 1713120.7921470543, 850484.7763225038, 1332166.1020819854, 931993.5925440514]

# Create the plot for Workload 100C-0I-0D with a red line
plt.figure(figsize=(10, 6))
plt.plot(threads, workload_100C_0I_0D_throughput, marker='^', label='100C-0I-0D', color='red')

# Customize the plot for Workload 100C-0I-0D
plt.title('''Coarse Grained Synchronization
Throughput vs. Threads for Workload 100C-0I-0D
Problem Size: 2000''')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Workload 0C-0I-50D
threads_0C_0I_50D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_0C_0I_50D = [8078849.5718209725, 2260448.925156536, 1.9331142470520005E7, 1.6915703411333524E7, 2.3555738766857076E7, 1.840874783697213E7, 2.1894214453830574E7, 2.0206685526239824E7, 2.5727608940344106E7]

# Create the plot for Workload 0C-0I-50D
plt.figure(figsize=(10, 6))
plt.plot(threads_0C_0I_50D, throughput_0C_0I_50D, marker='o', label='0C-0I-50D', color='blue')
plt.title('Coarse Grained Synchronization\nThroughput vs. Threads for Workload 0C-0I-50D\nProblem Size: 20000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Data for Workload 50C-25I-25D
threads_50C_25I_25D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_50C_25I_25D = [45528.32203092739, 25203.302439125204, 13647.221707134375, 49169.88934316403, 30368.921660329688, 23505.629598288793, 29009.478605388653, 16421.759582155366, 29224.641048346326]

# Create the plot for Workload 50C-25I-25D
plt.figure(figsize=(10, 6))
plt.plot(threads_50C_25I_25D, throughput_50C_25I_25D, marker='s', label='50C-25I-25D', color='green')
plt.title('Coarse Grained Synchronization\nThroughput vs. Threads for Workload 50C-25I-25D\nProblem Size: 20000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Data for Workload 100C-0I-0D
threads_100C_0I_0D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_100C_0I_0D = [3327787.021630616, 6759954.03231258, 1.1013215859030837E7, 1.171028748755782E7, 1.1777349213125857E7, 1.3459131347662823E7, 1.3146794920954894E7, 1.5227653418608192E7, 9890096.304812768]

# Create the plot for Workload 100C-0I-0D
plt.figure(figsize=(10, 6))
plt.plot(threads_100C_0I_0D, throughput_100C_0I_0D, marker='^', label='100C-0I-0D', color='red')
plt.title('Coarse Grained Synchronization\nThroughput vs. Threads for Workload 100C-0I-0D\nProblem Size: 20000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Fine Grained Synchronization**

# %%
import matplotlib.pyplot as plt

# Data
threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]
workload_0C_0I_50D = [116735.1513, 491243.5831, 510620.9150, 465152.3374, 1116320.6073, 718617.9540, 894207.7692, 807502.8551, 810873.8179]
workload_50C_25I_25D = [56720.8540, 655479.8112, 388153.5535, 363812.7577, 703068.0130, 638320.9605, 908705.3977, 726061.9953, 812776.8521]
workload_100C_0I_0D = [569703.1846, 469296.2902, 465598.1190, 524613.0978, 758646.1959, 235248.7285, 784467.5427, 917936.4788, 1322620.1104]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(threads, workload_0C_0I_50D, marker='o', label='0C-0I-50D')
plt.plot(threads, workload_50C_25I_25D, marker='s', label='50C-25I-25D')
plt.plot(threads, workload_100C_0I_0D, marker='^', label='100C-0I-0D')

# Customize the plot
plt.title(''' Fine Grained Syncronization
Throughput vs. Threads for Different Workloads
problem size - 2000''')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]
workload_0C_0I_50D = [
    1.1133E7, 6111348.77, 7879134.08, 8585410.53, 1.1373E7, 1.5547E7, 3.9421E6, 1.8505E7, 1.7049E7
]
workload_50C_25I_25D = [
    1.0589E7, 9104565.94, 7735746.89, 7303801.63, 8.9826E6, 1.5082E7, 1.7383E7, 1.6203E7, 2.1539E7
]
workload_100C_0I_0D = [
    1.4380E7, 7107320.54, 1.1062E7, 1.0165E7, 9.4197E6, 1.2827E7, 1.6583E7, 1.5442E7, 1.8958E7
]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(threads, workload_0C_0I_50D, marker='o', label='0C-0I-50D')
plt.plot(threads, workload_50C_25I_25D, marker='s', label='50C-25I-25D')
plt.plot(threads, workload_100C_0I_0D, marker='^', label='100C-0I-0D')

# Customize the plot
plt.title(''' Fine Grained Syncronization
Throughput vs. Threads for Different Workloads
problem size - 20000''')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]
workload_0C = [5.6139E7, 3.5152E7, 5.5270E7, 6.7911E7, 7.1780E7, 7.2849E7, 7.1108E7, 7.8492E7, 6.8571E7]
workload_50C = [4.1740E7, 3.2744E7, 6.8552E7, 5.5419E7, 6.1129E7, 5.7950E7, 5.6173E7, 6.3128E7, 6.2106E7]
workload_100C = [1.6890E7, 1.0724E7, 1.8787E7, 2.1277E7, 2.1229E7, 2.0345E7, 2.1281E7, 2.2485E7, 2.2185E7]

# Create a figure and axis
plt.figure(figsize=(10, 6))
plt.title(''' Fine Grained Syncronization
Throughput vs. Threads for Different Workloads
problem size - 200000''')
plt.xlabel("Threads")
plt.ylabel("Throughput (ops/s)")

# Plot the data
plt.plot(threads, workload_0C, marker='o', label='0C-0I-50D')
plt.plot(threads, workload_50C, marker='o', label='50C-25I-25D')
plt.plot(threads, workload_100C, marker='o', label='100C-0I-0D')

# Add a legend
plt.legend()

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Optimistic Synchronization**

# %%
import matplotlib.pyplot as plt

# Data
threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]

workload_0C_0I_50D = [
    5.32052E-4,
    8.95401E-4,
    0.004532197,
    0.004101939,
    0.003802096,
    0.001891069,
    0.002327779,
    0.002626052,
    0.001609461,
]

workload_50C_25I_25D = [
    0.276741507,  # Threads 1
    0.006534343,  # Threads 2
    0.031898795,  # Threads 4
    0.030859119,  # Threads 6
    0.025811607,  # Threads 8
    0.045809996,  # Threads 10
    0.061949835,  # Threads 12
    0.08895875,   # Threads 14
    0.101583978,
]

workload_100C_0I_0D = [
    4.40251E-4,  # Threads 1
    5.50174E-4,  # Threads 2
    0.001558213,  # Threads 4
    0.001155917,  # Threads 6
    0.002052104,  # Threads 8
    0.006648768,  # Threads 10
    0.002694403,  # Threads 12
    0.002373134,  # Threads 14
    0.002431761,  # Threads 16
]

# Create the plot
plt.figure(figsize=(12, 6))

# Plot 0C-0I-50D workload
plt.plot(threads, workload_0C_0I_50D, marker='o', label='0C-0I-50D')

# Plot 50C-25I-25D workload
plt.plot(threads, workload_50C_25I_25D, marker='s', label='50C-25I-25D')

# Plot 100C-0I-0D workload
plt.plot(threads, workload_100C_0I_0D, marker='^', label='100C-0I-0D')

# Customize the plot
plt.title('''Optimistic Synchronization
Throughput vs. Threads for Different Workloads
problem size 2000''')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]
workload_0C_0I_50D = [ 5.59404E-4,   # Threads 1
    7.86954E-4,   # Threads 2
    9.24854E-4,   # Threads 4
    0.004532197,  # Threads 6
    0.003802096,  # Threads 8
    0.001116402,  # Threads 10
    0.002327779,  # Threads 12
    0.00147098,   # Threads 14
    0.007036209   # Threads 16
                       ]
workload_50C_25I_25D = [ 16.503272039,  # Threads 1
    0.276741507,   # Threads 2
    0.689403498,   # Threads 4
    1.308468392,   # Threads 6
    1.95938631,    # Threads 8
    2.98837262,    # Threads 10
    4.275978172,   # Threads 12
    5.111532615,   # Threads 14
    6.119380076    # Threads 16
                         ]
workload_100C_0I_0D = [ 4.69738E-4,  # Threads 1
    0.001077037,  # Threads 2
    9.55882E-4,  # Threads 4
    0.034221979,  # Threads 6
    0.013119177,  # Threads 8
    0.001866464,  # Threads 10
    0.027623156,  # Threads 12
    0.002373134,  # Threads 14
    0.002124142  # Threads 16
                        ]

# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(threads, workload_0C_0I_50D, marker='o', label='0C-0I-50D')
plt.plot(threads, workload_50C_25I_25D, marker='s', label='50C-25I-25D')
plt.plot(threads, workload_100C_0I_0D, marker='^', label='100C-0I-0D')

# Customize the plot
plt.title('''Optimistic Synchronization
Throughput vs. Threads for Different Workloads
problem size 20000''')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]
workload_0C_0I_50D = [195471.3204478639, 3119239.1551852673, 3345600.5352960858, 1283574.5669112448, 5830334.355099429, 4323292.342757534, 6564892.595621764, 6417093.670774677, 3714044.5666777776]
workload_50C_25I_25D = [124977.11356607822, 328172.86965351016, 183300.17204095898, 113053.39353501909, 127981.82658062554, 126221.78905148164, 114374.9834156274, 80489.1778074756, 48670.55511752225]
workload_100C_0I_0D = [1845141.0056756537, 2461308.2345528295, 1179412.180969005, 3036383.464867778, 323974.178286068, 1225311.955233963, 3403730.0342869074, 3464859.3960057106, 3432297.1871681]

# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(threads, workload_0C_0I_50D, marker='o', label='0C-0I-50D')
plt.plot(threads, workload_50C_25I_25D, marker='s', label='50C-25I-25D')
plt.plot(threads, workload_100C_0I_0D, marker='^', label='100C-0I-0D')

# Customize the plot
plt.title('''Optimistic Synchronization
Throughput vs. Threads for Different Workloads
problem size 200000''')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Lazy Syncronization**

# %%
import matplotlib.pyplot as plt

# Data
threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]

# Workload: 0C-0I-50D
workload_0C_0I_50D = [227583.0678197542, 563427.8953150971, 656221.8029694037, 854506.0954768144, 1032018.3699269848, 869686.2172128295, 1450028.3963894292, 879927.5945293644, 852914.8364535801]

# Create the plot for Workload: 0C-0I-50D
plt.figure(figsize=(12, 6))
plt.plot(threads, workload_0C_0I_50D, marker='o', label='0C-0I-50D', color='blue')

# Customize the plot
plt.title('Lazy Syncronization\nThroughput vs. Threads for Workload 0C-0I-50D\nProblem Size: 2000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# Workload: 50C-25I-25D
workload_50C_25I_25D = [157198.10104693935, 119306.82733319413, 82406.26287597857, 74357.55076142131, 77735.33644339458, 173872.82593765267, 91601.16547216203, 64277.11886078907, 66567.48111979816]

# Create the plot for Workload: 50C-25I-25D
plt.figure(figsize=(12, 6))
plt.plot(threads, workload_50C_25I_25D, marker='s', label='50C-25I-25D', color='green')

# Customize the plot
plt.title('Lazy Syncronization \nThroughput vs. Threads for Workload 50C-25I-25D\nProblem Size: 2000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# Workload: 100C-0I-0D
workload_100C_0I_0D = [423370.0254022015, 505254.64834276476, 824725.2633966309, 727484.3590862795, 785653.9587138845, 1713120.7921470543, 850484.7763225038, 1332166.1020819854, 931993.5925440514]

# Create the plot for Workload: 100C-0I-0D
plt.figure(figsize=(12, 6))
plt.plot(threads, workload_100C_0I_0D, marker='^', label='100C-0I-0D', color='red')

# Customize the plot
plt.title('Lazy Syncronization\nThroughput vs. Threads for Workload 100C-0I-0D\nProblem Size: 2000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
threads = [1, 2, 4, 6, 8, 10, 12, 14, 16]

# Workload: 0C-0I-50D
workload_0C_0I_50D_throughput = [4350284.94366381, 6059504.332545598, 9748251.407403797, 9857558.282813348, 1.0350761427887538E7, 1.3242752903473573E7, 1.9892580067634773E7, 1.1389521640091116E7, 2.0009004051823318E7]

# Workload: 50C-25I-25D
workload_50C_25I_25D_throughput = [49348.84202942178, 34355.50700740688, 26467.875278078114, 19061.0464959284, 18714.016309312, 15379.479348335166, 11994.93453914412, 10355.843653153444, 10341.127223327003]

# Workload: 100C-0I-0D
workload_100C_0I_0D_throughput = [1.034340091021928E7, 1.097032527014426E7, 1.762502753910553E7, 1.0263779123473262E7, 1.762386271010949E7, 2.0215088542087812E7, 1.4884274763712138E7, 1.0856079404466502E7, 2.2007042253521126E7]

# Create individual graphs for each workload
plt.figure(figsize=(12, 6))

# Workload: 0C-0I-50D
plt.plot(threads, workload_0C_0I_50D_throughput, marker='o', label='0C-0I-50D', color='blue')

# Customize the plot
plt.title('Lazy Syncronization\nThroughput vs. Threads for Workload 0C-0I-50D\nProblem Size: 20000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# Workload: 50C-25I-25D
plt.figure(figsize=(12, 6))
plt.plot(threads, workload_50C_25I_25D_throughput, marker='s', label='50C-25I-25D', color='green')
plt.title('Lazy Syncronization \nThroughput vs. Threads for Workload 50C-25I-25D\nProblem Size: 20000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Workload: 100C-0I-0D
plt.figure(figsize=(12, 6))
plt.plot(threads, workload_100C_0I_0D_throughput, marker='^', label='100C-0I-0D', color='red')
plt.title('Throughput vs. Threads''Lazy Syncronization\nThroughput vs. Threads for Workload 100C-0I-0D\nProblem Size: 20000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Workload 0C-0I-50D
threads_0C_0I_50D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_0C_0I_50D = [7.423904974016333E7, 7.966540529774944E7, 9.947279419078882E7, 2.4684247336158308E8, 3.1776294884016526E8, 4.174493842621582E8, 2.4104129840912744E8, 3.6490642756607413E8, 3.54421407052986E8]

# Create the plot for Workload 0C-0I-50D
plt.figure(figsize=(10, 6))
plt.plot(threads_0C_0I_50D, throughput_0C_0I_50D, marker='o', label='0C-0I-50D', color='blue')
plt.title('Lazy Syncronization\nThroughput vs. Threads for Workload 0C-0I-50D\nProblem Size: 200000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Data for Workload 50C-25I-25D
threads_50C_25I_25D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_50C_25I_25D = [1810.0620378490778, 1609.5879251057418, 1322.003206645029, 1783.4091884683962, 1372.0015452242865, 2999.0926985816336, 673.2619815835922, 1872.5195270502636, 446.200091049064]

# Create the plot for Workload 50C-25I-25D
plt.figure(figsize=(10, 6))
plt.plot(threads_50C_25I_25D, throughput_50C_25I_25D, marker='s', label='50C-25I-25D', color='green')
plt.title('Lazy Syncronization \nThroughput vs. Threads for Workload 50C-25I-25D\nProblem Size: 200000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Data for Workload 100C-0I-0D
threads_100C_0I_0D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_100C_0I_0D = [4.5920007347201176E7, 1.1566042100393246E8, 2.4874074995336112E8, 1.8215489237681773E8, 3.228931223764934E8, 2.826775214834916E8, 2.18161985274066E8, 4.488905989483134E8, 4.1393940961891705E8]

# Create the plot for Workload 100C-0I-0D
plt.figure(figsize=(10, 6))
plt.plot(threads_100C_0I_0D, throughput_100C_0I_0D, marker='^', label='100C-0I-0D', color='red')
plt.title('Lazy Syncronization\nThroughput vs. Threads for Workload 100C-0I-0D\nProblem Size: 200000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##**Non Blocking Syncronization**

# %%
import matplotlib.pyplot as plt

# Data for Workload 0C-0I-50D
threads_0C_0I_50D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_0C_0I_50D = [894154.4651838605, 9411764.705882354, 1.08560541499981E7, 1.491453968759011E7, 9158557.527189467, 1.4101886127269521E7, 1.5048588128921254E7, 1.5991629524203332E7, 1.4191215992081301E7]

# Create the plot for Workload 0C-0I-50D
plt.figure(figsize=(10, 6))
plt.plot(threads_0C_0I_50D, throughput_0C_0I_50D, marker='o', label='0C-0I-50D', color='blue')
plt.title('Non Blocking Syncronization\nThroughput vs. Threads for Workload 0C-0I-50D\nProblem Size: 2000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()

# Data for Workload 50C-25I-25D
threads_50C_25I_25D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_50C_25I_25D = [170023.46833933488, 482756.5398425007, 264875.82356515445, 181795.45738600855, 459487.34537389287, 272359.2732572146, 238032.66006456636, 217225.31924325094, 186227.86725444839]

# Create the plot for Workload 50C-25I-25D
plt.figure(figsize=(10, 6))
plt.plot(threads_50C_25I_25D, throughput_50C_25I_25D, marker='s', label='50C-25I-25D', color='green')
plt.title('Non Blocking Syncronization \nThroughput vs. Threads for Workload 50C-25I-25D\nProblem Size: 2000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()

# Data for Workload 100C-0I-0D
threads_100C_0I_0D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_100C_0I_0D = [5611420.3627222115, 9264620.729588883, 1.2192036771182902E7, 1.0100312941362632E7, 1.4277224436183484E7, 1.419613666336843E7, 1.2795455054364689E7, 1.1664644794902219E7, 1.4191215992081301E7]

# Create the plot for Workload 100C-0I-0D
plt.figure(figsize=(10, 6))
plt.plot(threads_100C_0I_0D, throughput_100C_0I_0D, marker='^', label='100C-0I-0D', color='red')
plt.title('Non Blocking Syncronization\nThroughput vs. Threads for Workload 100C-0I-0D\nProblem Size: 2000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()

# Show all three plots
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Workload 0C-0I-50D
threads_0C_0I_50D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_0C_0I_50D = [6.735911840385833E7, 9.054895302773063E7, 1.0537851964255607E8, 4.366812227074236E7, 1.8161180476730987E8, 6.7082218650466755E7, 1.4541788252173996E8, 1.8793005780191636E8, 1.7951468205705875E8]

# Create the plot for Workload 0C-0I-50D
plt.figure(figsize=(10, 6))
plt.plot(threads_0C_0I_50D, throughput_0C_0I_50D, marker='o', label='0C-0I-50D', color='blue')
plt.title('Non Blocking Syncronization\nThroughput vs. Threads for Workload 0C-0I-50D\nProblem Size: 20000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()

# Data for Workload 50C-25I-25D
threads_50C_25I_25D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_50C_25I_25D = [85589.8439502, 56640.536499161724, 42121.77196615078, 51347.32162742768, 52766.322577411185, 42539.95960689602, 36102.13791219757, 33730.75084681501, 28477.49880128908]

# Create the plot for Workload 50C-25I-25D
plt.figure(figsize=(10, 6))
plt.plot(threads_50C_25I_25D, throughput_50C_25I_25D, marker='s', label='50C-25I-25D', color='green')
plt.title('Non Blocking Syncronization \nThroughput vs. Threads for Workload 50C-25I-25DD\nProblem Size: 20000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()

# Data for Workload 100C-0I-0D
threads_100C_0I_0D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_100C_0I_0D = [4.823135616927277E7, 1.084010840108401E8, 1.6463683172881022E8, 1.1352885525070955E8, 1.540066761894128E8, 1.585937177856511E8, 1.7458786352466708E8, 1.3810110974106044E8, 1.3598215234250507E8]

# Create the plot for Workload 100C-0I-0D
plt.figure(figsize=(10, 6))
plt.plot(threads_100C_0I_0D, throughput_100C_0I_0D, marker='^', label='100C-0I-0D', color='red')
plt.title('Non Blocking Syncronization\nThroughput vs. Threads for Workload 100C-0I-0D\nProblem Size: 20000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()

# Show all three plots
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Workload 0C-0I-50D
threads_0C_0I_50D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_0C_0I_50D = [
    5.0654455565911573E8, 5.762310456000438E8, 8.178570917410747E8, 1.0954742307945108E9,
    1.465424231156018E9, 1.225114854517611E9, 1.1473196700308628E9, 1.2084154048795815E9, 1.1526339486717694E9
]

# Create the plot for Workload 0C-0I-50D
plt.figure(figsize=(10, 6))
plt.plot(threads_0C_0I_50D, throughput_0C_0I_50D, marker='o', label='0C-0I-50D', color='blue')
plt.title('Non Blocking Syncronization\nThroughput vs. Threads for Workload 0C-0I-50D\nProblem Size: 200000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()

# Data for Workload 50C-25I-25D
threads_50C_25I_25D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_50C_25I_25D = [
    4783.994867774702, 4568.330708061194, 4377.159909557371, 4423.737789399775,
    5256.403308418023, 3088.6269790324873, 2066.9089687998944, 1281.410016963359, 1160.7909710051918
]

# Create the plot for Workload 50C-25I-25D
plt.figure(figsize=(10, 6))
plt.plot(threads_50C_25I_25D, throughput_50C_25I_25D, marker='s', label='50C-25I-25D', color='green')
plt.title('Non Blocking Syncronization\nThroughput vs. Threads for Workload 50C-25I-25D\nProblem Size: 200000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()

# Data for Workload 100C-0I-0D
threads_100C_0I_0D = [1, 2, 4, 6, 8, 10, 12, 14, 16]
throughput_100C_0I_0D = [
    2.4532352039251763E8, 5.014102162331558E8, 5.343421713528476E8, 9.433354139119964E8,
    9.789417395060506E8, 9.561372056890165E8, 1.099446795020972E9, 1.0055361949935789E9, 1.470870783082412E9
]

# Create the plot for Workload 100C-0I-0D
plt.figure(figsize=(10, 6))
plt.plot(threads_100C_0I_0D, throughput_100C_0I_0D, marker='^', label='100C-0I-0D', color='red')
plt.title('Non Blocking Syncronization\nThroughput vs. Threads for Workload 100C-0I-0D\nProblem Size: 200000')
plt.xlabel('Threads')
plt.ylabel('Throughput (ops/s)')
plt.grid(True)
plt.legend()
plt.tight_layout()

# Show all three plots
plt.show()
